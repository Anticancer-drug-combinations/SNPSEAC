# %%
# arr1 <- read.csv('array1.csv', header=FALSE)
# arr2 <- read.csv('array2.csv', header=FALSE)

# print(arr1)
# print(arr2)


# # 设置列名
# colnames(arr1) <- "Highly similar subgroup5"
# colnames(arr2) <- "Low similar subgroup5"

# # 绘制箱线图
# x11(width = 10, height = 10)
# layout(matrix(c(1,1,2,2), 2, 2, byrow = T), heights = c(4,1))
# boxplot(arr1, arr2, outline = FALSE, col = rainbow(10), side = 1, las = 2, ylab = "")
# mtext("Pearson", side = 2, line = 3, font.lab = 2)

# # 保存EPS文件
# dev.copy2eps()

# %%
# Sys.setenv("DISPLAY" = "192.168.0.1:0")
Sys.setenv("DISPLAY" = ":0")

# %%
# # Read in the CSV files
# arr1 <- read.csv('array1.csv', header=FALSE)
# arr2 <- read.csv('array2.csv', header=FALSE)

# # Set column names
# colnames(arr1) <- "Highly similar subgroup5"
# colnames(arr2) <- "Low similar subgroup5"

# x11(width = 10, height = 10)
# M <- cbind(arr1, arr2)

# # 利用layout函数分割屏幕
# layout(matrix(c(1,1,2,2), 2, 2, byrow = T), heights = c(4,1))
# boxplot(M, outline=FALSE,col = rainbow(10),side = 1,las=2,ylab=""
# )#outline=TRUE意思是显示异常值
# mtext("Pearson", side = 2, line =3, font.lab=2)

# dev.copy2eps()

# %%
# 读入CSV文件
arr1 <- read.csv('array1.csv', header=FALSE)
arr2 <- read.csv('array2.csv', header=FALSE)
colnames(arr1) <- "Highly similar drugs"
colnames(arr2) <- "Low similar drugs"
# 合并两个array为一个M
M <- c(arr1, arr2)

x11(width = 10, height = 10)
layout(matrix(c(1,1,2,2), 2, 2, byrow = T), heights = c(4,1))
boxplot(M, outline=FALSE,col = rainbow(10),side = 1,las=1,ylab="")#outline=TRUE意思是显示异常值
mtext("Tanimoto", side = 2, line =3, font.lab=2)

dev.copy2eps()
# Out:
# png
#   2
# plot without title
